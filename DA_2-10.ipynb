# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("IMDB.csv")
df
# Out:
#      color      director_name  duration        gross  \
# 0    Color    Martin Scorsese       240  116866727.0
# 1    Color        Shane Black       195  408992272.0
# 2   color   Quentin Tarantino       187   54116191.0
# 3    Color   Kenneth Lonergan       186      46495.0
# 4    Color      Peter Jackson       186  258355354.0
# ..     ...                ...       ...          ...
# 94   Color      Steve McQueen       134   56667870.0
# 95   Color   Richard J. Lewis       134    7501404.0
# 96   Color    Paul Greengrass       134  107100855.0
# 97   Color         David Ayer       134   85707116.0
# 98   Color     Clint Eastwood         5   47034272.0
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1                Action|Adventure|Sci-Fi                           Iron Man 3
# 2   Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# ...

# %%
df2 = df.drop(['color', 'language'], axis = 1, inplace = False)
df2
# Out:
#         director_name  duration        gross  \
# 0     Martin Scorsese       240  116866727.0
# 1         Shane Black       195  408992272.0
# 2   Quentin Tarantino       187   54116191.0
# 3    Kenneth Lonergan       186      46495.0
# 4       Peter Jackson       186  258355354.0
# ..                ...       ...          ...
# 94      Steve McQueen       134   56667870.0
# 95   Richard J. Lewis       134    7501404.0
# 96    Paul Greengrass       134  107100855.0
# 97         David Ayer       134   85707116.0
# 98     Clint Eastwood         5   47034272.0
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1                Action|Adventure|Sci-Fi                           Iron Man 3
# 2   Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# 3                                  Drama                             Margaret
# ...

# %%
df
# Out:
#      color      director_name  duration        gross  \
# 0    Color    Martin Scorsese       240  116866727.0
# 1    Color        Shane Black       195  408992272.0
# 2   color   Quentin Tarantino       187   54116191.0
# 3    Color   Kenneth Lonergan       186      46495.0
# 4    Color      Peter Jackson       186  258355354.0
# ..     ...                ...       ...          ...
# 94   Color      Steve McQueen       134   56667870.0
# 95   Color   Richard J. Lewis       134    7501404.0
# 96   Color    Paul Greengrass       134  107100855.0
# 97   Color         David Ayer       134   85707116.0
# 98   Color     Clint Eastwood         5   47034272.0
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1                Action|Adventure|Sci-Fi                           Iron Man 3
# 2   Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   director_name         88 non-null     object
#  1   duration              99 non-null     int64
#  2   gross                 91 non-null     float64
#  3   genres                98 non-null     object
#  4   movie_title           99 non-null     object
#  5   title_year            99 non-null     int64
#  6   country               99 non-null     object
#  7   budget                95 non-null     float64
#  8   imdb_score            99 non-null     float64
#  9   actors                99 non-null     object
#  10  movie_facebook_likes  99 non-null     int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 8.6+ KB

# %%
df2.describe()
# Out:
#          duration         gross   title_year        budget  imdb_score  \
# count   99.000000  9.100000e+01    99.000000  9.500000e+01   99.000000
# mean   155.494949  1.541914e+08  1976.444444  1.048570e+08    6.892929
# std     72.797927  1.399503e+08   255.880601  7.703169e+07    1.925514
# min    -50.000000  4.122900e+04   202.000000  1.735000e+04   -7.500000
# 25%    138.500000  4.720632e+07  2012.000000  4.000000e+07    6.550000
# 50%    143.000000  1.156040e+08  2013.000000  8.000000e+07    7.200000
# 75%    155.000000  2.374894e+08  2014.000000  1.740000e+08    7.850000
# max    650.000000  6.232795e+08  2016.000000  2.500000e+08    8.800000
#
#        movie_facebook_likes
# count             99.000000
# mean           66045.707071
# std            58108.860365
# min                0.000000
# 25%            25000.000000
# 50%            54000.000000
# 75%            85500.000000
# max           349000.000000

# %%
df2.isnull()
# Out:
#     director_name  duration  gross  genres  movie_title  title_year  country  \
# 0           False     False  False   False        False       False    False
# 1           False     False  False   False        False       False    False
# 2           False     False  False   False        False       False    False
# 3           False     False  False   False        False       False    False
# 4           False     False  False   False        False       False    False
# ..            ...       ...    ...     ...          ...         ...      ...
# 94          False     False  False   False        False       False    False
# 95          False     False  False   False        False       False    False
# 96          False     False  False   False        False       False    False
# 97          False     False  False   False        False       False    False
# 98          False     False  False   False        False       False    False
#
# ...

# %%
df2.isnull().any()
# Out:
# director_name            True
# duration                False
# gross                    True
# genres                   True
# movie_title             False
# title_year              False
# country                 False
# budget                   True
# imdb_score              False
# actors                  False
# movie_facebook_likes    False
# dtype: bool

# %%
df2.isnull().sum()
# Out:
# director_name           11
# duration                 0
# gross                    8
# genres                   1
# movie_title              0
# title_year               0
# country                  0
# budget                   4
# imdb_score               0
# actors                   0
# movie_facebook_likes     0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 24

# %%
df2['director_name'].unique()
# Out:
# array(['Martin Scorsese', 'Shane Black', 'Quentin Tarantino',
#        'Kenneth Lonergan', 'Peter Jackson', nan, 'Edward Hall',
#        'Joss Whedon', 'Tom Tykwer', 'Null', 'Christopher Spencer',
#        'Christopher Nolan', 'F. Gary Gray', 'Richard Linklater',
#        'Michael Bay', 'Tom Hooper', 'Kathryn Bigelow', 'Ridley Scott',
#        'Denis Villeneuve', 'Gnana Rajasekaran', 'Marc Webb', 'Nan',
#        'Mike Leigh', 'Gore Verbinski', 'David Fincher', 'Bryan Singer',
#        'Jay Oliva', 'Paul Thomas Anderson', 'Sam Mendes',
#        'Michael Patrick King', 'Tate Taylor', 'Francis Lawrence',
#        'Steven Spielberg', 'Guillaume Canet', 'Adam McKay', 'Zack Snyder',
#        'Baz Luhrmann', 'Timur Bekmambetov', 'Justin Chadwick',
#        'Oliver Stone', 'David Dobkin', 'Ryan Murphy', 'James Wan',
#        'Derek Cianfrance', "Gavin O'Connor", 'Gary Ross',
#        'Terrence Malick', 'Robert Zemeckis', 'Darren Aronofsky',
# ...

# %%
df2['director_name'] = np.where(df2['director_name'].isnull(), '', df2['director_name'])
df2['director_name'] = np.where(df2['director_name'] == 'Null', '', df2['director_name'])
df2['director_name'] = np.where(df2['director_name'] == 'Nan', '', df2['director_name'])

# nan =
# Nan = object
# N/A= object

# %%
df2['director_name'].unique()
# Out:
# array(['Martin Scorsese', 'Shane Black', 'Quentin Tarantino',
#        'Kenneth Lonergan', 'Peter Jackson', '', 'Edward Hall',
#        'Joss Whedon', 'Tom Tykwer', 'Christopher Spencer',
#        'Christopher Nolan', 'F. Gary Gray', 'Richard Linklater',
#        'Michael Bay', 'Tom Hooper', 'Kathryn Bigelow', 'Ridley Scott',
#        'Denis Villeneuve', 'Gnana Rajasekaran', 'Marc Webb', 'Mike Leigh',
#        'Gore Verbinski', 'David Fincher', 'Bryan Singer', 'Jay Oliva',
#        'Paul Thomas Anderson', 'Sam Mendes', 'Michael Patrick King',
#        'Tate Taylor', 'Francis Lawrence', 'Steven Spielberg',
#        'Guillaume Canet', 'Adam McKay', 'Zack Snyder', 'Baz Luhrmann',
#        'Timur Bekmambetov', 'Justin Chadwick', 'Oliver Stone',
#        'David Dobkin', 'Ryan Murphy', 'James Wan', 'Derek Cianfrance',
#        "Gavin O'Connor", 'Gary Ross', 'Terrence Malick',
#        'Robert Zemeckis', 'Darren Aronofsky', 'James Mangold',
# ...

# %%
df2["director_name"].isnull().sum()
# Out:
# 0

# %%
plt.boxplot(df['duration'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ad2d33afac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ad2d33f4040>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ad2d33af820>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ad2d33f4580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ad2d33f4820>],
#  'means': []}

# %%
df2['duration'].unique()
# Out:
# array([240, 195, 187, 186, 183, -50, 180, 173, 172, 158, 170, 169, 167,
#        165, 580, 164, 157, 156, 154, 153, 151, 150, 650, 149, 148, 147,
#        146, 144, 143, 142, 141, 140, 139, 138, 137, 136, 135, 134,   5])

# %%
# prompt: I want to drop a movie with -50 duration
# Assuming 'duration' is the column with movie duration
df2 = df2[df2.duration != -50]

# %%
# prompt: give me another way to drop -50 movie duration instead of df2 = df2[df2.duration != -50]

df2.drop(df2[df2.duration == -50].index, inplace=True)
# Out:
# <ipython-input-18-3d43b53a4fe4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(df2[df2.duration == -50].index, inplace=True)

# %%
df2['duration'].unique()
# Out:
# array([240, 195, 187, 186, 183, 180, 173, 172, 158, 170, 169, 167, 165,
#        580, 164, 157, 156, 154, 153, 151, 150, 650, 149, 148, 147, 146,
#        144, 143, 142, 141, 140, 139, 138, 137, 136, 135, 134,   5])

# %%
df2['gross'].unique()
# Out:
# array([1.16866727e+08, 4.08992272e+08, 5.41161910e+07, 4.64950000e+04,
#        2.58355354e+08, 3.30249062e+08,            nan, 6.23279547e+08,
#        2.70985800e+07, 1.02515793e+08, 5.96961760e+07, 1.87991439e+08,
#        1.61029270e+08, 2.53592000e+07, 1.62804648e+08, 2.45428137e+08,
#        4.48130642e+08, 2.55108370e+08, 1.48775460e+08, 9.57207160e+07,
#        1.05219735e+08, 1.83635922e+08, 3.52358779e+08, 6.09628780e+07,
#        2.62030663e+08, 2.28430993e+08, 6.50070450e+07, 1.82204440e+08,
#        3.95850000e+06, 8.92899100e+07, 1.67735396e+08, 2.33914986e+08,
#        2.92568851e+08, 8.09331800e+06, 2.00074175e+08, 4.07197282e+08,
#        9.53289370e+07, 1.69705587e+08, 4.24645577e+08, 7.98833590e+07,
#        5.28224180e+07, 4.12290000e+04, 1.63772740e+07, 1.54985087e+08,
#        2.17531200e+06, 2.91021565e+08, 3.04360277e+08, 1.44812796e+08,
#        7.23060650e+07, 2.02853933e+08, 4.07999255e+08, 4.58991599e+08,
# ...

# %%
pd.set_option('display.max_rows', None)
df2['gross']
# Out:
# 0     116866727.0
# 1     408992272.0
# 2      54116191.0
# 3         46495.0
# 4     258355354.0
# 5     330249062.0
# 7             NaN
# 8     623279547.0
# 9     623279547.0
# 10     27098580.0
# 11    102515793.0
# 12     59696176.0
# 13    187991439.0
# 14    161029270.0
# 15     25359200.0
# 16    162804648.0
# 17    245428137.0
# 18    448130642.0
# 19    255108370.0
# 20    148775460.0
# 21    148775460.0
# 22     95720716.0
# 23    105219735.0
# 24    183635922.0
# 25    352358779.0
# 26     60962878.0
# 27            NaN
# 28    262030663.0
# 29    228430993.0
# 30     65007045.0
# 31     65007045.0
# 32    182204440.0
# 33      3958500.0
# 34     89289910.0
# 35    167735396.0
# 36    233914986.0
# 37            NaN
# 38    292568851.0
# 39      8093318.0
# 40    200074175.0
# 41    407197282.0
# 42     95328937.0
# 43    169705587.0
# 44    424645577.0
# 45     79883359.0
# 46     52822418.0
# 47        41229.0
# 48     16377274.0
# 49    154985087.0
# 50      2175312.0
# ...

# %%
df2['gross'].fillna(0, inplace=True)

pd.set_option('display.max_rows', None)
df2['gross']
# Out:
# <ipython-input-22-33ee5f66008f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['gross'].fillna(0, inplace=True)
# 0     116866727.0
# 1     408992272.0
# 2      54116191.0
# 3         46495.0
# 4     258355354.0
# 5     330249062.0
# 7             0.0
# 8     623279547.0
# 9     623279547.0
# 10     27098580.0
# 11    102515793.0
# 12     59696176.0
# 13    187991439.0
# 14    161029270.0
# 15     25359200.0
# 16    162804648.0
# 17    245428137.0
# 18    448130642.0
# 19    255108370.0
# 20    148775460.0
# 21    148775460.0
# 22     95720716.0
# 23    105219735.0
# 24    183635922.0
# 25    352358779.0
# 26     60962878.0
# 27            0.0
# 28    262030663.0
# 29    228430993.0
# 30     65007045.0
# 31     65007045.0
# 32    182204440.0
# 33      3958500.0
# 34     89289910.0
# ...

# %%
df2['genres'].unique()
# Out:
# array(['Biography|Comedy|Crime|Drama', 'Action|Adventure|Sci-Fi',
#        'Crime|Drama|Mystery|Thriller|Western', 'Drama',
#        'Adventure|Fantasy', 'Drama|Romance', 'Drama|Sci-Fi',
#        'Crime|Drama|Mystery|Thriller', nan, 'Adventure|Drama|Sci-Fi',
#        'Biography|Crime|Drama|History|Music', 'Drama|Western',
#        'Action|Thriller', 'Drama|Musical|Romance',
#        'Drama|History|Thriller', 'Action|Adventure|Drama|History',
#        'Adventure|Drama|Thriller|Western', 'Biography|Drama|History',
#        'Action|Adventure|Fantasy', 'Action|Adventure|Drama',
#        'Biography|Drama|History|War', 'Action|Adventure|Western',
#        'Action|Adventure|Fantasy|Sci-Fi|Thriller',
#        'Action|Animation|Crime|Sci-Fi|Thriller',
#        'Action|Adventure|Sci-Fi|Thriller',
#        'Comedy|Crime|Drama|Mystery|Romance', 'Action|Adventure|Thriller',
#        'Comedy|Drama|Romance', 'Adventure|Sci-Fi|Thriller', 'Drama|War',
# ...

# %%
df2['genres'].fillna('general', inplace=True)

pd.set_option('display.max_rows', None)
df2['genres']
# Out:
# <ipython-input-24-a38556c67d23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['genres'].fillna('general', inplace=True)
# 0                 Biography|Comedy|Crime|Drama
# 1                      Action|Adventure|Sci-Fi
# 2         Crime|Drama|Mystery|Thriller|Western
# 3                                        Drama
# 4                            Adventure|Fantasy
# 5                      Action|Adventure|Sci-Fi
# 7                                Drama|Romance
# 8                      Action|Adventure|Sci-Fi
# 9                      Action|Adventure|Sci-Fi
# 10                                Drama|Sci-Fi
# 11                Crime|Drama|Mystery|Thriller
# 12                                     general
# 13                      Adventure|Drama|Sci-Fi
# ...

# %%
df2["budget"].unique()
# Out:
# array([1.000e+08, 2.000e+08, 4.400e+07, 1.400e+07, 2.250e+08, 2.500e+08,
#              nan, 2.200e+08, 1.020e+08, 9.000e+07, 2.200e+07, 1.650e+08,
#        2.800e+07, 4.000e+06, 2.100e+08, 6.100e+07, 4.000e+07, 1.350e+08,
#        1.950e+08, 4.600e+07, 2.300e+08, 1.080e+08, 1.400e+08, 6.500e+07,
#        2.150e+08, 3.500e+06, 1.600e+08, 2.000e+07, 2.450e+08, 2.500e+07,
#        1.300e+08, 6.600e+07, 5.000e+07, 2.550e+07, 3.200e+07, 1.780e+08,
#        1.050e+08, 1.735e+04, 7.800e+07, 3.500e+07, 4.500e+07, 6.000e+07,
#        1.900e+08, 1.500e+07, 8.500e+07, 3.000e+07, 3.100e+07, 1.250e+08,
#        8.000e+07, 1.200e+08, 1.700e+08, 7.500e+07, 7.000e+07, 1.400e+06,
#        5.500e+07, 6.800e+07])

# %%
pd.set_option('display.max_rows', None)
df2['budget']
# Out:
# 0     100000000.0
# 1     200000000.0
# 2      44000000.0
# 3      14000000.0
# 4     225000000.0
# 5     250000000.0
# 7             NaN
# 8     220000000.0
# 9     220000000.0
# 10    102000000.0
# 11     90000000.0
# 12     22000000.0
# 13    165000000.0
# 14     28000000.0
# 15      4000000.0
# 16    100000000.0
# 17    210000000.0
# 18    250000000.0
# 19    250000000.0
# 20     61000000.0
# 21     61000000.0
# 22     40000000.0
# 23    200000000.0
# 24    135000000.0
# 25    195000000.0
# 26     46000000.0
# 27            NaN
# 28    230000000.0
# 29    108000000.0
# 30    140000000.0
# 31    140000000.0
# 32     65000000.0
# 33            NaN
# 34    215000000.0
# 35     61000000.0
# 36    200000000.0
# 37      3500000.0
# 38    160000000.0
# 39     20000000.0
# 40    245000000.0
# 41    250000000.0
# 42    100000000.0
# 43     25000000.0
# 44    130000000.0
# 45     66000000.0
# 46     50000000.0
# 47     25500000.0
# 48     32000000.0
# 49    178000000.0
# 50     50000000.0
# ...

# %%
df2['budget'].fillna(0, inplace=True)

pd.set_option('display.max_rows', None)
df2['budget']
# Out:
# <ipython-input-27-55673d526722>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['budget'].fillna(0, inplace=True)
# 0     100000000.0
# 1     200000000.0
# 2      44000000.0
# 3      14000000.0
# 4     225000000.0
# 5     250000000.0
# 7             0.0
# 8     220000000.0
# 9     220000000.0
# 10    102000000.0
# 11     90000000.0
# 12     22000000.0
# 13    165000000.0
# 14     28000000.0
# 15      4000000.0
# 16    100000000.0
# 17    210000000.0
# 18    250000000.0
# 19    250000000.0
# 20     61000000.0
# 21     61000000.0
# 22     40000000.0
# 23    200000000.0
# 24    135000000.0
# 25    195000000.0
# 26     46000000.0
# 27            0.0
# 28    230000000.0
# 29    108000000.0
# 30    140000000.0
# 31    140000000.0
# 32     65000000.0
# 33            0.0
# 34    215000000.0
# ...

# %%
df2['title_year'].unique()
# Out:
# array([2013, 2015, 2011,  202, 2012, 2014, 2010, 2016,  205])

# %%
df2['title_year'] = np.where(df2['title_year'] == '202', '2002', df2['title_year'])
df2['title_year'] = np.where(df2['title_year'] == '205', '2005', df2['title_year'])
# Out:
# <ipython-input-29-0bbec3fda1b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['title_year'] = np.where(df2['title_year'] == '202', '2002', df2['title_year'])
# <ipython-input-29-0bbec3fda1b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['title_year'] = np.where(df2['title_year'] == '205', '2005', df2['title_year'])

# %%
df2['title_year'].unique()
# Out:
# array(['2013', '2015', '2011', '202', '2012', '2014', '2010', '2016',
#        '2005'], dtype=object)

# %%
df2['imdb_score'].unique()
# Out:
# array([ 8.2,  7.2,  7.9,  6.5,  6.9,  8.1, -7.5,  7.8,  5.6,  8.6,  8. ,
#         8.5,  5.7,  7.5,  7.6,  7.4,  6.7,  6.3,  7. ,  6.1,  6.8,  8.4,
#         8.8,  4.3,  7.1,  7.3,  3. ,  6. ,  5.8,  5.3,  6.4,  6.6, -1.2,
#         5.9,  8.7])

# %%
df2['imdb_score'] = np.where(df2['imdb_score'] == '-7.5', '7.5', df2['imdb_score'])
df2['imdb_score'] = np.where(df2['imdb_score'] == '-1.2', '1.2', df2['imdb_score'])
# Out:
# <ipython-input-35-1f3fc4a9c28e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['imdb_score'] = np.where(df2['imdb_score'] == '-7.5', '7.5', df2['imdb_score'])
# <ipython-input-35-1f3fc4a9c28e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['imdb_score'] = np.where(df2['imdb_score'] == '-1.2', '1.2', df2['imdb_score'])

# %%
df2['imdb_score'].unique()
# Out:
# array(['8.2', '7.2', '7.9', '6.5', '6.9', '8.1', '7.5', '7.8', '5.6',
#        '8.6', '8.0', '8.5', '5.7', '7.6', '7.4', '6.7', '6.3', '7.0',
#        '6.1', '6.8', '8.4', '8.8', '4.3', '7.1', '7.3', '3.0', '6.0',
#        '5.8', '5.3', '6.4', '6.6', '1.2', '5.9', '8.7'], dtype=object)
